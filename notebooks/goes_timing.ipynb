# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.append('../')
import timing
from pathlib import Path

# %%
import xarray as xr
import numpy as np
import pandas as pd

# %%
from make_sample import open_index, band_dir_path, read_scene

# %%
from importlib import reload
import timing

# %%
dt = pd.to_datetime('2020-10-01')

# %%
L1B_DIR = Path('../l1b')
ABI_SCAN_DIR = Path('../ancil/abi_scan_schedule/')

# %%
timeline_file = ABI_SCAN_DIR / 'ABI-Timeline05B_Mode 6A_20190612-183017.nc'

# %%
timeline = xr.open_dataset(timeline_file)

# %%
reload(timing)
# Out:
# <module 'timing' from '../timing.py'>

# %%
time_offset = timing.goes_pixel_time_offset(ABI_SCAN_DIR)

# %%
imshow(time_offset)
colorbar()

# %%
mask = 
timeline.FD_pixel_times.astype(np.float32)#.plot.imshow()
# Out:
# <xarray.DataArray 'FD_pixel_times' (FD_cols: 5424, FD_rows: 5424)>
# array([[-4.1436311e+09, -4.1436311e+09, -4.1436311e+09, ...,
#          5.5996934e+11,  5.5996934e+11,  5.5996934e+11],
#        [-4.1413389e+09, -4.1413389e+09, -4.1413389e+09, ...,
#          5.5997170e+11,  5.5997170e+11,  5.5997170e+11],
#        [-4.1390472e+09, -4.1390472e+09, -4.1390472e+09, ...,
#          5.5997392e+11,  5.5997392e+11,  5.5997392e+11],
#        ...,
#        [ 8.2803860e+09,  8.2803860e+09,  8.2803860e+09, ...,
#          5.7239339e+11,  5.7239339e+11,  5.7239339e+11],
#        [ 8.2826778e+09,  8.2826778e+09,  8.2826778e+09, ...,
#          5.7239568e+11,  5.7239568e+11,  5.7239568e+11],
#        [ 8.2849695e+09,  8.2849695e+09,  8.2849695e+09, ...,
#          5.7239798e+11,  5.7239798e+11,  5.7239798e+11]], dtype=float32)
# Dimensions without coordinates: FD_cols, FD_rows

# %%
band_dir = band_dir_path(L1B_DIR, dt, 'g16', 'temp_11_00um')

# %%
files = list(band_dir.glob('*'))

# %%
ds = xr.open_dataset(files[0])

# %%
ds.t
# Out:
# <xarray.DataArray 't' ()>
# array('2020-10-01T00:05:04.935158016', dtype='datetime64[ns]')
# Coordinates:
#     t        datetime64[ns] 2020-10-01T00:05:04.935158016
#     y_image  float32 0.0
#     x_image  float32 0.0
# Attributes:
#     long_name:      J2000 epoch mid-point between the start and end image sca...
#     standard_name:  time
#     axis:           T
#     bounds:         time_bounds
