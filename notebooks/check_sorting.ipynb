# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ..
# Out:
# /data/cphillips/isccp-ng/isccp_l1g_prototype

# %%
import utils

# %%
import numpy as np
import pandas as pd
import xarray as xr

# %%
wmo_id = xr.open_dataset('composite_cache/wmo_id.nc')
sample_mode = xr.open_dataset('composite_cache/sample_mode.nc', mask_and_scale=False)

# %%
sample_mode.sample_mode.shape
# Out:
# (3, 3600, 7200)

# %%
ids = np.full(2**12, -1, dtype=np.int8)
for i,(k,v) in enumerate(sorted(utils.WMO_IDS.items())):
    ids[v] = i

# %%
(wmo_id.wmo_id.isel(layer=0)>0).plot.imshow()

# %%
imshow(ids[wmo_id.wmo_id.isel(layer=0).values], vmin=-1, vmax=ids.max(), cmap='tab10')

# %%
sample_mode.sample_mode.isel(layer=0).plot.imshow()
